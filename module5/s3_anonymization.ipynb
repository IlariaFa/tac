# %% [markdown]
# # Anonymisation de données

# %% [markdown]
# ## Imports

# %%
from pprint import pprint
from faker import Faker
from faker.providers import internet

# %% [markdown]
# "Faker is a Python package that generates fake data for you. Whether you need to bootstrap your database, create good-looking XML documents, fill-in your persistence to stress test it, or anonymize data taken from a production service, Faker is for you."
#
# https://faker.readthedocs.io/en/master/

# %% [markdown]
# "Use `faker.Faker()` to create and initialize a faker generator, which can generate data by accessing properties named after the type of data you want."

# %%
fake = Faker()

# %% [markdown]
# ## Créer un faux nom

# %%
print(fake.name())
# Out:
# Pam Erickson

# %%
# Il est possible de créer plusieurs faux noms, ici en français, avec une boucle.
fake_fr = Faker('fr_FR')
for _ in range(10):
    print(fake_fr.name())
# Out:
# Adélaïde Chauveau Le Mahe
# Capucine de Dijoux
# Nathalie Perrier
# Lucy-Aurélie Masson
# Madeleine Pereira
# Catherine Aubert
# Gilles Marchal
# Marine Le Lopez
# Laurence Dias
# Jules-Édouard Blin

# %%
# Même chose en néerlandais.
fake_nl = Faker('nl_NL')
for _ in range(10):
    print(fake_nl.name())
# Out:
# Ivy van Schevinghuizen
# Kyan Verheuvel
# Yasmine Bouwhuisen
# Jasmijn Karels
# Jolijn Uittenbosch
# Dave Oosterhout
# Jari Zuidweg
# Faas van Grinsven
# Lotte ter Waarbeek-Horrocks
# Aron Janse

# %% [markdown]
# ## Créer une fausse adresse

# %%
# Pour créer une fausse adresse.
print(fake.address())
# Out:
# 174 Margaret Harbors Suite 250
# New Brittanyton, TX 07689

# %% [markdown]
# ## Créer une fausse adresse IP

# %%
fake.add_provider(internet)
print(fake.ipv4_public())
# Out:
# 170.43.204.212

# %% [markdown]
# ## Créer un faux profil complet

# %%
profile = fake_fr.simple_profile()
pprint(profile)
# Out:
# {'address': '803, avenue Patrick Bègue\n60870 Georges-les-Bains',
#  'birthdate': datetime.date(1986, 4, 18),
#  'mail': 'eric57@club-internet.fr',
#  'name': 'Xavier Gaillard du Dos Santos',
#  'sex': 'M',
#  'username': 'gmartin'}
